# %%
#######################################################################################################
# Import libraries
from sklearn.ensemble import AdaBoostRegressor
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, explained_variance_score
from sklearn.model_selection import cross_val_score, train_test_split
import matplotlib.pyplot as plt
#######################################################################################################

data_set = ['../data/data-SNA1.csv', '../data/data-SNF1.csv', '../data/data-SNA3.csv', '../data/data-SNF3.csv', '../data/data-MNF1.csv', '../data/data-MNA1.csv', '../data/data-MNF3.csv', '../data/data-MNA3.csv']


used_max_depth = 5
used_lr = 0.1 


for i in data_set:
    print("DATA_SET: " + i)
    X = pd.read_csv(i)
    y = X.pop('Operatieduur').values
    
#     X_train, X_test, y_train, y_test = train_test_split(X, y)
    
#     model = AdaBoostRegressor(
#         n_estimators=100,
# #         max_depth=used_max_depth,
#         random_state=0
#     )
#     model.fit(X_train, y_train)
    
#     errors = [mean_squared_error(y_test, y_pred) for y_pred in model.staged_predict(X_test)]
#     best_n_estimators = np.argmin(errors)
    
#     print("\nBest n estimators: ")
#     print(best_n_estimators)
    
    model = AdaBoostRegressor(
        n_estimators=100,
#         max_depth=used_max_depth,
        learning_rate=used_lr,
        random_state=0
    )
    model.fit(X, y)

    importances = model.feature_importances_
    indices = np.argsort(importances)[::-1]

    predicted = model.predict(X)
    print('\nR2:', r2_score(y, predicted))
    print('EVS:', explained_variance_score(y, predicted))
    print('MAE:', mean_absolute_error(y, predicted))
    print('MSE:', mean_squared_error(y, predicted))


    # Print the feature ranking
    print("Feature ranking:")

    for f in range(10):
        print("%d. %s (%f)" % (f + 1, X.columns[indices[f]], importances[indices[f]]))

    plt.figure(figsize=[8.0,8.0])
    plt.xlabel('Actual')
    plt.ylabel('Predicted')
    plt.scatter(y, predicted)
    plt.plot(y, y, color='r')
    plt.grid(True)
    plt.show()

    score = np.mean(cross_val_score(model, X, y, cv=10, scoring='r2'))
    print("\ncross validation score: ")
    print(score)
    print("\n")
# Out:
# DATA_SET: ../data/data-SNA1.csv
#
# R2: 0.41857948356330343
# EVS: 0.4585002437314747
# MAE: 57.6368424518822
# MSE: 5496.974371911903
# Feature ranking:
# 1. Benadering_U (0.205137)
# 2. Benadering_Volledige sternotomie (0.139976)
# 3. Euroscore1 (0.104907)
# 4. Euroscore2 (0.072544)
# 5. Bentall procedure_J (0.048586)
# 6. Vervanging aorta ascendens_J (0.047268)
# 7. Dagdeel_Ochtend (0.044574)
# 8. MVR_J (0.041267)
# 9. MVP_J (0.038276)
# 10. VSD_J (0.025748)
# cross validation score:
# -0.11682680330914445
#
#
# DATA_SET: ../data/data-SNF1.csv
#
# R2: 0.3106351906068112
# EVS: 0.348392219075512
# MAE: 53.66632667473923
# MSE: 5012.685339151906
# Feature ranking:
# 1. Benadering_Volledige sternotomie (0.095961)
# 2. Euroscore2 (0.087296)
# 3. Euroscore1 (0.085634)
# 4. Benadering_U (0.082527)
# 5. Bentall procedure_J (0.080073)
# 6. MVR_J (0.067219)
# 7. MVP_J (0.058929)
# 8. Dagdeel_Ochtend (0.057635)
# 9. Vervanging aorta ascendens_J (0.036609)
# 10. Aorta chirurgie_N (0.033673)
# cross validation score:
# -0.06697705620700492
#
#
# DATA_SET: ../data/data-SNA3.csv
#
# R2: 0.4178106276550877
# EVS: 0.4598634358432524
# MAE: 57.76446485484792
# MSE: 5504.243432950644
# Feature ranking:
# 1. Benadering_U (0.195597)
# 2. Benadering_Volledige sternotomie (0.149494)
# 3. Euroscore1 (0.110107)
# 4. Euroscore2 (0.079953)
# 5. Dagdeel_Ochtend (0.044296)
# 6. Bentall procedure_J (0.043586)
# 7. Vervanging aorta ascendens_J (0.042252)
# 8. MVR_J (0.041086)
# 9. MVP_J (0.037771)
# 10. VSD_J (0.025609)
# cross validation score:
# -0.09481451696089761
#
#
# DATA_SET: ../data/data-SNF3.csv
#
# R2: 0.3100229406015639
# EVS: 0.3412791781069944
# MAE: 53.5959792663677
# MSE: 5017.137287646203
# Feature ranking:
# 1. Benadering_Volledige sternotomie (0.102775)
# 2. Euroscore2 (0.091482)
# 3. Euroscore1 (0.076542)
# 4. Bentall procedure_J (0.075771)
# 5. Benadering_U (0.073242)
# 6. MVR_J (0.071344)
# 7. Dagdeel_Ochtend (0.054730)
# 8. MVP_J (0.052526)
# 9. Aorta chirurgie_N (0.036260)
# 10. Vervanging aorta ascendens_J (0.032110)
# cross validation score:
# -0.06541795308954573
#
#
# DATA_SET: ../data/data-MNF1.csv
#
# R2: 0.2348661171716171
# EVS: 0.27051076916197625
# MAE: 55.79008837104368
# MSE: 5563.636763411646
# Feature ranking:
# 1. Euroscore1 (0.111582)
# 2. Dagdeel_Ochtend (0.072458)
# 3. Bentall procedure_J (0.068153)
# 4. HLM_J (0.062658)
# 5. MVP_N (0.053005)
# 6. MVR_N (0.045655)
# 7. Aorta chirurgie_N (0.044047)
# 8. BMI (0.043752)
# 9. Bentall procedure_N (0.042314)
# 10. Leeftijd (0.036530)
# cross validation score:
# -0.007370434570054462
#
#
# DATA_SET: ../data/data-MNA1.csv
#
# R2: 0.311589193926748
# EVS: 0.3371013297109361
# MAE: 61.546675341017284
# MSE: 6508.501938534348
# Feature ranking:
# 1. Euroscore1 (0.143668)
# 2. HLM_J (0.060675)
# 3. Dagdeel_Ochtend (0.059082)
# 4. MVP_N (0.049727)
# 5. Bentall procedure_J (0.041436)
# 6. Bentall procedure_N (0.039644)
# 7. MVP_J (0.036070)
# 8. MVR_N (0.035871)
# 9. HLM_N (0.034509)
# 10. Anesthesioloog (0.031752)
# cross validation score:
# -0.1634203295563431
#
#
# DATA_SET: ../data/data-MNF3.csv
#
# R2: 0.2392071381302212
# EVS: 0.2744678035895224
# MAE: 55.557332456346984
# MSE: 5532.071223918413
# Feature ranking:
# 1. Euroscore1 (0.111383)
# 2. Dagdeel_Ochtend (0.067122)
# 3. HLM_J (0.060064)
# 4. Bentall procedure_N (0.058214)
# 5. Bentall procedure_J (0.055339)
# 6. Aorta chirurgie_J (0.052259)
# 7. MVR_J (0.049504)
# 8. MVP_J (0.047856)
# 9. BMI (0.044273)
# 10. MVP_N (0.040349)
# cross validation score:
# -0.0037482089678402388
#
#
# DATA_SET: ../data/data-MNA3.csv
#
# R2: 0.2955187580051323
# EVS: 0.3241026990915754
# MAE: 62.238389167788036
# MSE: 6660.4380534619195
# Feature ranking:
# 1. Euroscore1 (0.161108)
# 2. Dagdeel_Ochtend (0.064145)
# 3. Bentall procedure_J (0.053383)
# 4. HLM_N (0.049431)
# 5. MVR_J (0.048364)
# 6. MVP_J (0.047729)
# 7. MVP_N (0.041530)
# 8. HLM_J (0.039534)
# 9. Vervanging aorta ascendens_N (0.029394)
# 10. Bentall procedure_N (0.028444)
# cross validation score:
# -0.17808118087817065
